# %%
# Does not write all data

import os
import glob
import h5py
import numpy as np

dataset_dir = "../../MillionSongSubset"
csv_dir = "../../MillionSongSubsetCSV"

# Loop over all subdirectories in the first level
for sub_dir_1 in sorted(os.listdir(dataset_dir)):
    # Ignore any non-directory entries
    if not os.path.isdir(os.path.join(dataset_dir, sub_dir_1)):
        continue
        
    # Loop over all subdirectories in the second level
    for sub_dir_2 in sorted(os.listdir(os.path.join(dataset_dir, sub_dir_1))):
        if not os.path.isdir(os.path.join(dataset_dir, sub_dir_1, sub_dir_2)):
            continue
            
        # Loop over all subdirectories in the third level
        for sub_dir_3 in sorted(os.listdir(os.path.join(dataset_dir, sub_dir_1, sub_dir_2))):
            if not os.path.isdir(os.path.join(dataset_dir, sub_dir_1, sub_dir_2, sub_dir_3)):
                continue
                
            # Use glob to find all the .h5 files in the fourth level
            h5_files = glob.glob(os.path.join(dataset_dir, sub_dir_1, sub_dir_2, sub_dir_3, "*.h5"))
            
            # Loop over each .h5 file and convert it to .csv
            for h5_file in h5_files:
                # Open the .h5 file
                with h5py.File(h5_file, 'r') as f:
                    # Get the dataset name and data
                    dataset_name = list(f.keys())[0]
                    data = np.array(f[dataset_name])

                # Construct the output filename for the .csv file and write the data to the file
                output_file = os.path.join(csv_dir, os.path.splitext(os.path.basename(h5_file))[0] + ".csv")
                dtype = [('data', 'U{}'.format(len(data[0])))]
                data_structured = np.array([(d,) for d in data], dtype=dtype)
                np.savetxt(output_file, data_structured, delimiter=",", fmt="%s")

print("Finished!")

# %%
import os
import glob
import h5py
import numpy as np
import csv

dataset_dir = "../../MillionSongSubset"
csv_dir = "../../MillionSongSubsetCSV"

# Define the relevant data columns
data_columns = ['ID', 'Year', 'Duration', 'Mode']

# Loop over all subdirectories in the first level
for sub_dir_1 in sorted(os.listdir(dataset_dir)):
    # Ignore any non-directory entries
    if not os.path.isdir(os.path.join(dataset_dir, sub_dir_1)):
        continue
        
    # Loop over all subdirectories in the second level
    for sub_dir_2 in sorted(os.listdir(os.path.join(dataset_dir, sub_dir_1))):
        if not os.path.isdir(os.path.join(dataset_dir, sub_dir_1, sub_dir_2)):
            continue
            
        # Loop over all subdirectories in the third level
        for sub_dir_3 in sorted(os.listdir(os.path.join(dataset_dir, sub_dir_1, sub_dir_2))):
            if not os.path.isdir(os.path.join(dataset_dir, sub_dir_1, sub_dir_2, sub_dir_3)):
                continue
                
            # Use glob to find all the .h5 files in the fourth level
            h5_files = glob.glob(os.path.join(dataset_dir, sub_dir_1, sub_dir_2, sub_dir_3, "*.h5"))
            
            # Loop over each .h5 file and convert it to .csv
            for h5_file in h5_files:
                # Open the .h5 file
                with h5py.File(h5_file, 'r') as f:
                    # Get the relevant data
                    data = {}
                    data['ID'] = os.path.splitext(os.path.basename(h5_file))[0]
                    data['Year'] = f['metadata']['songs'][0]['year']
                    data['Duration'] = f['analysis']['songs'][0]['duration']
                    data['Mode'] = f['analysis']['songs'][0]['mode']

                    # Write the data to a new .csv file
                    csv_filename = os.path.join(csv_dir, data['ID'] + ".csv")
                    with open(csv_filename, mode='w', newline='') as csv_file:
                        writer = csv.DictWriter(csv_file, fieldnames=data_columns)
                        writer.writeheader()
                        writer.writerow(data)
print("Finished!")
